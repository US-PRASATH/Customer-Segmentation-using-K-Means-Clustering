# %%
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv("./Customer Data.csv")

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 3     C10004  1666.670542           0.636364    1499.00           1499.00
# 4     C10005   817.714335           1.000000      16.00             16.00
# ...      ...          ...                ...        ...               ...
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8946  C19187    19.183215           1.000000     300.00              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#      CUST_ID      BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001    40.900749           0.818182      95.40              0.00
# 1     C10002  3202.467416           0.909091       0.00              0.00
# 2     C10003  2495.148862           1.000000     773.17            773.17
# 4     C10005   817.714335           1.000000      16.00             16.00
# 5     C10006  1809.828751           1.000000    1333.28              0.00
# ...      ...          ...                ...        ...               ...
# 8943  C19184     5.871712           0.500000      20.90             20.90
# 8945  C19186    28.493517           1.000000     291.12              0.00
# 8947  C19188    23.398673           0.833333     144.40              0.00
# 8948  C19189    13.457564           0.833333       0.00              0.00
# 8949  C19190   372.708075           0.666667    1093.25           1093.25
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
df.describe()
# Out:
#             BALANCE  BALANCE_FREQUENCY     PURCHASES  ONEOFF_PURCHASES  \
# count   8636.000000        8636.000000   8636.000000       8636.000000
# mean    1601.224893           0.895035   1025.433874        604.901438
# std     2095.571300           0.207697   2167.107984       1684.307803
# min        0.000000           0.000000      0.000000          0.000000
# 25%      148.095189           0.909091     43.367500          0.000000
# 50%      916.855459           1.000000    375.405000         44.995000
# 75%     2105.195853           1.000000   1145.980000        599.100000
# max    19043.138560           1.000000  49039.570000      40761.250000
#
#        INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# count             8636.000000   8636.000000          8636.000000
# mean               420.843533    994.175523             0.496000
# std                917.245182   2121.458303             0.401273
# min                  0.000000      0.000000             0.000000
# ...

# %%
scaler = StandardScaler()

# %%
df[['BALANCE',	'BALANCE_FREQUENCY',	'PURCHASES',	'ONEOFF_PURCHASES',	'INSTALLMENTS_PURCHASES',	'CASH_ADVANCE',	'PURCHASES_FREQUENCY',	'ONEOFF_PURCHASES_FREQUENCY',	'PURCHASES_INSTALLMENTS_FREQUENCY',	'CASH_ADVANCE_FREQUENCY',	'CASH_ADVANCE_TRX',	'PURCHASES_TRX',	'CREDIT_LIMIT',	'PAYMENTS',	'MINIMUM_PAYMENTS',	'PRC_FULL_PAYMENT',	'TENURE']] = scaler.fit_transform(df[['BALANCE',	'BALANCE_FREQUENCY',	'PURCHASES',	'ONEOFF_PURCHASES',	'INSTALLMENTS_PURCHASES',	'CASH_ADVANCE',	'PURCHASES_FREQUENCY',	'ONEOFF_PURCHASES_FREQUENCY',	'PURCHASES_INSTALLMENTS_FREQUENCY',	'CASH_ADVANCE_FREQUENCY',	'CASH_ADVANCE_TRX',	'PURCHASES_TRX',	'CREDIT_LIMIT',	'PAYMENTS',	'MINIMUM_PAYMENTS',	'PRC_FULL_PAYMENT',	'TENURE']])

# %%
df
# Out:
#      CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001 -0.744625          -0.370047  -0.429184         -0.359160
# 1     C10002  0.764152           0.067679  -0.473208         -0.359160
# 2     C10003  0.426602           0.505405  -0.116413          0.099909
# 4     C10005 -0.373910           0.505405  -0.465825         -0.349660
# 5     C10006  0.099551           0.505405   0.142062         -0.359160
# ...      ...       ...                ...        ...               ...
# 8943  C19184 -0.761342          -1.902089  -0.463563         -0.346751
# 8945  C19186 -0.750546           0.505405  -0.338865         -0.359160
# 8947  C19188 -0.752977          -0.297095  -0.406572         -0.359160
# 8948  C19189 -0.757721          -0.297095  -0.473208         -0.359160
# 8949  C19190 -0.586278          -1.099590   0.031295          0.289957
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
def optimize_k_means(data,max_k):
    means = []
    inertias = []

    for k in range(1, max_k):
        kmeans = KMeans(n_clusters=k)
        kmeans.fit(data)

        means.append(k)
        inertias.append(kmeans.inertia_)

    #Generate the elbow plot
    fig = plt.subplots(figsize=(10,5))
    plt.plot(means, inertias, 'o-')
    plt.xlabel('Number of Clusters')
    plt.ylabel('Inertia')
    plt.grid(True)
    plt.show()

# %%
optimize_k_means(df[['PURCHASES','CASH_ADVANCE']],10)

# %%
kmeans = KMeans(n_clusters=3)
kmeans.fit(df[['PURCHASES','CASH_ADVANCE']])
# Out:
# KMeans(n_clusters=3)

# %%
df['kmeans_3'] = kmeans.labels_

# %%
df
# Out:
#      CUST_ID   BALANCE  BALANCE_FREQUENCY  PURCHASES  ONEOFF_PURCHASES  \
# 0     C10001 -0.744625          -0.370047  -0.429184         -0.359160
# 1     C10002  0.764152           0.067679  -0.473208         -0.359160
# 2     C10003  0.426602           0.505405  -0.116413          0.099909
# 4     C10005 -0.373910           0.505405  -0.465825         -0.349660
# 5     C10006  0.099551           0.505405   0.142062         -0.359160
# ...      ...       ...                ...        ...               ...
# 8943  C19184 -0.761342          -1.902089  -0.463563         -0.346751
# 8945  C19186 -0.750546           0.505405  -0.338865         -0.359160
# 8947  C19188 -0.752977          -0.297095  -0.406572         -0.359160
# 8948  C19189 -0.757721          -0.297095  -0.473208         -0.359160
# 8949  C19190 -0.586278          -1.099590   0.031295          0.289957
#
#       INSTALLMENTS_PURCHASES  CASH_ADVANCE  PURCHASES_FREQUENCY  \
# ...

# %%
plt.scatter(x=df['PURCHASES'],y=df['CASH_ADVANCE'],c=df['kmeans_3'])
#plt.xlim(-0.1,1)
#plt.ylim(3,1.5)
plt.show()
